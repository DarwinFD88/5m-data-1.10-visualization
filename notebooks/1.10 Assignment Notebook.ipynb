# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %% [markdown]
# Question: How to plot a line and set the color to red and style to dash in a matplotlib plot?

# %%
x = [1, 2, 3, 4]
y = [1, 4, 9, 16]

# %%
plt.plot(x, y, color='red', linestyle='--')
plt.show()

# %%
plt.plot(x, y, 'ro--')

# %% [markdown]
# Question: How to plot a histogram with 30 bins for `data` in matplotlib?

# %%
data = np.random.randn(1000)

# %%
plt.hist(data, bins=30)
plt.show()

# %% [markdown]
# Question: How do you create a bar plot in seaborn using the `tips` dataset to show the average tip amount per day?

# %%
tips = sns.load_dataset('tips')

# %%
sns.barplot(data=tips, x='day', y='tip')
# Out:
# /home/darwin/miniconda3/envs/pds/lib/python3.10/site-packages/seaborn/categorical.py:641: FutureWarning: The default of observed=False is deprecated and will be changed to True in a future version of pandas. Pass observed=False to retain current behavior or observed=True to adopt the future default and silence this warning.
#   grouped_vals = vals.groupby(grouper)
# <Axes: xlabel='day', ylabel='tip'>

# %% [markdown]
# Question: How to create a box plot for total_bill categorized by day in the `tips` dataset using seaborn?

# %%
sns.boxplot(data=tips, x='day', y='total_bill')
# Out:
# /home/darwin/miniconda3/envs/pds/lib/python3.10/site-packages/seaborn/categorical.py:641: FutureWarning: The default of observed=False is deprecated and will be changed to True in a future version of pandas. Pass observed=False to retain current behavior or observed=True to adopt the future default and silence this warning.
#   grouped_vals = vals.groupby(grouper)
# <Axes: xlabel='day', ylabel='total_bill'>
